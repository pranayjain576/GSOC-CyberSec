# %%
import json
import csv
import pandas as pd
import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()


with open('QAnon-posts.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

extracted_data = []
for post in data['posts']:
    if 'text' in post and 'post_metadata' in post and 'time' in post['post_metadata']:
        extracted_data.append((post['text'], post['post_metadata']['time']))

with open('extracted_data.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['text', 'time']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for text, time in extracted_data:
        writer.writerow({'text': text, 'time': time})

# %%
df = pd.read_csv('extracted_data.csv')
df_sorted = df.sort_values(by ='time')
df = df_sorted

# %%
def preprocess_text(tweet):
    tweet = re.sub(r'\r|\n', ' ', tweet.lower())
    tweet = re.sub(r"(?:\@|https?\://)\S+", "", tweet)
    tweet = re.sub(r'[^\x00-\x7f]', '', tweet)
    banned_list = string.punctuation
    table = str.maketrans('', '', banned_list)
    tweet = tweet.translate(table)
    tweet = ' '.join('' if ('$' in word) or ('&' in word) else word for word in tweet.split())
    tweet = re.sub(r"\s\s+", " ", tweet)
    tweet = re.sub(r'\d+', '', tweet)
    tokens = word_tokenize(tweet)
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    tweet = ' '.join(tokens)
    tweet = re.sub(r'\b(\w+)((\w)\3{2,})(\w*)\b', r'\1\3\4', tweet)
    tweet = re.sub(r'[\?\.\!]+(?=[\?\.\!])', '', tweet)
    tweet = ' '.join(tweet.split())
    tweet = re.sub(r'(?:http[s]?://)?(?:www\.)?(?:bit\.ly|goo\.gl|t\.co|tinyurl\.com|tr\.im|is\.gd|cli\.gs|u\.nu|url\.ie|tiny\.cc|alturl\.com|ow\.ly|bit\.do|adoro\.to)\S+', '', tweet)
    tweet = tweet.strip()
    return tweet

df['text'] = df['text'].apply(preprocess_text)

text_vals={}
num = 1
for i in range(200,df.shape[0],200):
    text_vals[num] = df['text'][i-200:i]
    num+=1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()

tfidf_matrices = {}
for interval_num, interval_text in text_vals.items():
    tfidf_matrices[interval_num] = tfidf_vectorizer.fit_transform(interval_text)

feature_names = tfidf_vectorizer.get_feature_names_out()

common_words_per_interval = {}
for interval_num, tfidf_matrix in tfidf_matrices.items():
    max_tfidf_indices = tfidf_matrix.max(axis=0).toarray().ravel().argsort()[-10:]
    common_words_per_interval[interval_num] = [feature_names[idx] for idx in max_tfidf_indices if idx < len(feature_names)]

for interval_num, common_words in common_words_per_interval.items():
    print(f"Interval {interval_num}:")
    for word in common_words:
        print(word)
    print()
# Out:
# Interval 1:
# boxprevent
# carried
# and
# date
# jesus
# benavides
# camp
# huber
# abolish
# le
#
# Interval 2:
# average
# carle
# checkmarks
# harbor
# inaction
# device
# generate
# civilian
# dan
# cast
#
# Interval 3:
# part
# formed
# displace
# billion
# minor
# department
# kc
# bathroom
# book
# mm
#
# Interval 4:
# bedroom
# crane
# attackedalteredreformatted
# illinois
# herself
# intimidation
# ensure
# adopting
# anons
# illicit
#
# Interval 5:
# betrayed
# ever
# kimmerling
# captain
# apology
# difficult
# guardian
# guise
# delegate
# application
#
# Interval 6:
# gu
# conformobey
# fvey
# controlled
# group
# buhr
# financially
# female
# happiness
# amen
#
# Interval 7:
# fact
# based
# sec
# journalist
# huber
# loss
# joseph
# antifa
# presence
# betrays
#
# Interval 8:
# butler
# been
# nazi
# project
# my
# offering
# prince
# bailout
# knowing
# data
#
# Interval 9:
# hospital
# lisa
# avoid
# increasing
# exhibiting
# making
# hillary
# pit
# extend
# leading
#
# Interval 10:
# grant
# attend
# cfi
# karli
# barsoomian
# influence
# deserter
# incline
# authority
# care
#
# Interval 11:
# msm
# many
# insurgent
# nsa
# number
# control
# bidens
# help
# admitting
# flag
#
# Interval 12:
# midnight
# dominance
# economy
# admin
# roams
# massachusetts
# basis
# same
# can
# scandal
#
# Interval 13:
# having
# called
# mark
# john
# lewd
# kimmerling
# such
# city
# not
# barter
#
# Interval 14:
# defend
# racist
# matter
# clean
# businessman
# closure
# guerrilla
# exec
# investigate
# file
#
# Interval 15:
# nonfvey
# carle
# mapping
# role
# disclosure
# now
# centralized
# gaming
# gap
# potus
#
# Interval 16:
# bribe
# california
# deputy
# department
# democracy
# delivery
# fired
# brother
# governed
# condemn
#
# Interval 17:
# fully
# coincidence
# floor
# darpa
# enforced
# designates
# leading
# behind
# concede
# david
#
# Interval 18:
# my
# created
# case
# clinton
# added
# discus
# exit
# paid
# apostate
# lynch
#
# Interval 19:
# homeland
# my
# hollywood
# earl
# payouts
# exist
# christine
# bodda
# deployed
# justify
#
# Interval 20:
# freeinformation
# like
# hell
# governed
# herself
# described
# miscounting
# blasio
# battleground
# added
#
# Interval 21:
# doom
# cdc
# his
# day
# misconduct
# god
# horse
# nelson
# gardner
# gather
#
# Interval 22:
# sadvisors
# designed
# clean
# included
# coord
# fathered
# betrays
# right
#
# Interval 23:
# marathon
# unknown
# spread
# october
# tracking
# organized
# something
# guccifer
# pb
# august

# %%
from transformers import BertTokenizer, BertModel
from sklearn.cluster import KMeans
import torch

# Load pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Define a function to preprocess text and extract BERT embeddings for each word
def preprocess_and_extract_embeddings(texts):
    input_ids_list = []
    word_embeddings_list = []
    for text in texts:
        # Tokenize the text and convert to token IDs
        input_ids = tokenizer.encode(text, add_special_tokens=False, truncation=True, max_length=512)
        
        # Check if the length of input_ids is less than 5
        if len(input_ids) < 5:
            continue  # Skip this text
        
        # Convert token IDs to tensor and cast to Long data type
        input_ids_tensor = torch.tensor(input_ids, dtype=torch.long).unsqueeze(0)  # Batch size 1
        
        # Forward pass through the model to get hidden states
        with torch.no_grad():
            outputs = model(input_ids_tensor)
            last_hidden_state = outputs.last_hidden_state
        
        # Get BERT embeddings for each word
        word_embeddings = last_hidden_state.squeeze(0).numpy()
        
        # Remove special tokens ([CLS] and [SEP]) and corresponding embeddings
        word_embeddings = word_embeddings[1:-1]
        
        input_ids_list.append(input_ids)
        word_embeddings_list.append(word_embeddings)
    
    # Concatenate input IDs and word embeddings
    input_ids_concatenated = np.concatenate(input_ids_list)
    word_embeddings_concatenated = np.concatenate(word_embeddings_list)
    
    return input_ids_concatenated, word_embeddings_concatenated

def identify_most_relevant_words(text, num_clusters=5):
    # Preprocess text and extract BERT embeddings for each word
    input_ids, word_embeddings = preprocess_and_extract_embeddings(text)
    
    # Apply k-means clustering
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    cluster_labels = kmeans.fit_predict(word_embeddings)
    
    # Get centroids of each cluster
    cluster_centroids = kmeans.cluster_centers_
    
    # Map each word to its corresponding cluster label
    word_clusters = {word: label for word, label in zip(tokenizer.tokenize(' '.join(text)), cluster_labels)}  # Concatenate texts
    
    # Identify the most relevant words in each cluster (centroid)
    relevant_words = []
    for centroid in cluster_centroids:
        # Find the nearest word embedding to the centroid
        nearest_idx = ((word_embeddings - centroid) ** 2).sum(axis=1).argmin()
        nearest_word = tokenizer.convert_ids_to_tokens([input_ids[nearest_idx]])[0]
        relevant_words.append(nearest_word)
    
    return relevant_words



def identify_most_relevant_words_per_interval(intervals, num_clusters=5):
    most_relevant_words_per_interval = {}
    for interval_num, interval_text in intervals.items():
        most_relevant_words = identify_most_relevant_words(interval_text, num_clusters)
        most_relevant_words_per_interval[interval_num] = most_relevant_words
    return most_relevant_words_per_interval

most_relevant_words_per_interval = identify_most_relevant_words_per_interval(text_vals)
for interval_num, words in most_relevant_words_per_interval.items():
    print(f"Interval {interval_num}:")
    print(words)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranay\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Interval 1:
# ['of', 'certain', 'protect', 'surgery', 'do']
# Interval 2:
# ['pig', 'code', '##yes', 'new', '##tan']
# Interval 3:
# ['no', 'important', 'anyone', 'id', 'thought']
# Interval 4:
# ['forget', 'this', 'everyone', '##gram', 'relevant']
# Interval 5:
# ['will', 'father', 'will', 'to', 'think']
# Interval 6:
# ['importance', 'interest', 'why', 'in', 'foundation']
# Interval 7:
# ['rogue', 'did', 'program', 'si', 'support']
# Interval 8:
# ['peter', 'to', 'power', '##eria', 'julie']
# Interval 9:
# ['control', 'thinking', '##sa', '##pot', 'public']
# Interval 10:
# ['prem', 'q', 'mil', 'there', 'do']
# Interval 11:
# ['wa', 'q', 'of', 'projection', 'a']
# Interval 12:
# ['we', '##rp', 'only', 'from', 'running']
# Interval 13:
# ['to', 'the', 'q', 'eliminate', 'fe']
# Interval 14:
# ['spin', 'before', 'food', 'what', 'evil']
# Interval 15:
# ['##au', '##j', 'wa', 'state', 'uk']
# Interval 16:
# ['coup', 'to', 'their', 'knowing', 'well']
# Interval 17:
# ['session', 'directly', 'result', 'experience', 'jc']
# Interval 18:
# ['you', 'warfare', 'secret', 'but', 'drop']
# Interval 19:
# ['accept', 'at', 'support', 'pot', 'name']
# Interval 20:
# ['reach', 'if', 'lock', '##ke', '##er']
# Interval 21:
# ['and', 'co', 'and', 'did', 'sc']
# Interval 22:
# ['it', 'anti', 'stand', 'q', 'mandated']
# Interval 23:
# ['unity', 'year', 'prevention', 'of', 'in']

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

def lda_topic_modeling(text_data):
    # Initialize CountVectorizer to convert text data into a bag-of-words representation
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(text_data)

    # Define number of topics
    n_topics = 10  # You can adjust this value based on the optimal number of topics found during hyperparameter tuning

    # Initialize LDA model
    lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)

    # Fit LDA model to the data
    lda_model.fit(X)

    return lda_model

# Apply topic modeling to each time window
topic_models = {}
for window, texts in text_vals.items():
    # Preprocess text data for the current time window
    preprocessed_texts = texts.apply(preprocess_text)

    # Apply LDA topic modeling
    lda_model = lda_topic_modeling(preprocessed_texts)

    # Store the LDA model for the current time window
    topic_models[window] = lda_model

# %%
def get_most_relevant_topics(lda_model, vectorizer, n_words=10):
    # Get the topic-term distribution matrix
    topic_term_matrix = lda_model.components_

    # Get the feature names (words) from the CountVectorizer
    feature_names = vectorizer.get_feature_names_out()

    # Initialize a dictionary to store the most relevant topics
    relevant_topics = {}

    # Iterate through each topic
    for topic_idx, topic_terms in enumerate(topic_term_matrix):
        # Get the top N words for the current topic
        top_words_indices = topic_terms.argsort()[-n_words:][::-1]
        top_words = [feature_names[idx] for idx in top_words_indices]

        # Store the top words for the current topic
        relevant_topics[f'Topic {topic_idx + 1}'] = top_words

    return relevant_topics

# Initialize CountVectorizer
vectorizer = CountVectorizer()

# Apply CountVectorizer to all text data to get the bag-of-words representation
X_all = vectorizer.fit_transform(df['text'])

# Iterate through each time window and extract the most relevant topics
relevant_topics_per_window = {}
for window, texts in text_vals.items():
    # Preprocess text data for the current time window
    preprocessed_texts = texts.apply(preprocess_text)

    # Apply CountVectorizer to the preprocessed text data
    X_window = vectorizer.transform(preprocessed_texts)

    # Retrieve the trained LDA model for the current time window
    lda_model = topic_models[window]

    # Extract the most relevant topics for the current time window
    relevant_topics = get_most_relevant_topics(lda_model, vectorizer)

    # Store the relevant topics for the current time window
    relevant_topics_per_window[window] = relevant_topics

# Print the most relevant topics for each time window
for window, topics in relevant_topics_per_window.items():
    print(f"Time Window {window}:")
    for topic, top_words in topics.items():
        print(f"- {topic}: {', '.join(top_words)}")
    print()
# Out:
# Time Window 1:
# - Topic 1: denies, admissible, chinarussia, compared, advise, clarification, calendar, crystal, blood, dem
# - Topic 2: calendar, disclosuresreports, disaster, deleteinstall, demean, dilute, controlling, countered, disclosing, denies
# - Topic 3: deleteinstall, clue, agent, denies, calendar, disaster, actspub, brush, disclosing, disclosuresreports
# - Topic 4: deleteinstall, denies, calendar, clue, actspub, disaster, demean, disclosuresreports, aggressive, conceal
# - Topic 5: denies, actspub, disguised, alwaleed, aggressive, deleteinstall, bxzja, brush, administrative, blizzard
# - Topic 6: deleteinstall, disruption, denies, actspub, disaster, brush, disclosuresreports, dilute, disclosing, calendar
# - Topic 7: alqaradawi, active, aag, buckle, customized, at, discovered, alarm, appellate, cripple
# - Topic 8: deleteinstall, denies, disaster, actspub, collins, calendar, dem, betterment, borderwall, bought
# - Topic 9: blm, disconcerting, actspub, denies, demean, advocate, clickonpreview, directly, acooper, competitor
# - Topic 10: actspub, deleteinstall, demean, disclosing, calendar, cult, commsinstall, blm, asecretplanbyagrouptodosomethingunlawfulorharmful, clue
#
# Time Window 2:
# - Topic 1: billion, brand, blank, adopting, boom, amid, aurn, balance, afford, algorithm
# - Topic 2: boom, ally, always, babcs, altitude, arrested, bahrain, billion, awans, antisessions
# - Topic 3: accepting, bite, approvedpage, alt, america, blank, at, brand, boom, billion
# - Topic 4: billion, bishop, blank, attach, approvedpage, absolute, associatesassistants, animal, apple, bio
# - Topic 5: brand, billion, accepting, blank, aug, boom, announced, antihydroxychloroquine, assembly, advisory
# - Topic 6: anarchist, anchor, address, attackwarning, blank, announced, ball, actspub, accurately, adopt
# - Topic 7: balance, billion, blank, attach, apple, against, boom, aggimagefailure, activeduty, accessed
# - Topic 8: billion, boukaus, approvedpage, branded, almost, bit, borger, attach, accepting, botsgoog
# - Topic 9: billion, attachment, blank, blmcom, balance, apple, apparatus, agent, asst, bignewsweek
# - Topic 10: billion, asst, brand, available, boukaus, approvedpage, borger, apple, aj, agenda
#
# Time Window 3:
# - Topic 1: belong, categorizedlabeled, castleonline, authored, carlo, appreciation, cheating, begging, attire, accomplish
# - Topic 2: carlo, categorizedlabeled, blanket, choose, attire, castleonline, batten, been, architect, cell
# - Topic 3: carefully, brightly, cfi, categorizedlabeled, accomplish, below, blake, appeal, catch, awandwspaki
# - Topic 4: aka, amongst, betterment, aiding, cayman, anons, benavides, belong, ahead, carle
# - Topic 5: attire, carlo, choose, accomplish, categorizedlabeled, chance, atmosphere, authored, accumulate, cheap
# - Topic 6: carlo, chance, accumulate, bidenchina, ascertained, bigger, ascension, cheap, architect, authored
# - Topic 7: carlo, car, categorizedlabeled, cheap, apostolic, activist, adv, accomplish, authored, chairceovpremoval
# - Topic 8: carlo, choose, categorizedlabeled, accumulate, activist, chance, belong, castleonline, castlerock, checkinzdestfc
# - Topic 9: categorizedlabeled, authored, carlo, cheap, cheating, agency, charged, chagaris, begging, amount
# - Topic 10: bull, categorizedlabeled, channel, ahead, below, checkinzdestfc, before, begging, castleonline, blake
#
# Time Window 4:
# - Topic 1: broker, ashton, built, bangko, assertive, bloodstream, cap, amid, cancer, calculated
# - Topic 2: broker, anticipated, acquiescence, acct, antiamerica, are, admit, bangko, brown, arrival
# - Topic 3: carried, broker, accesspowercontrol, campaign, assertive, built, capability, cap, bigamist, barrdurham
# - Topic 4: broker, candidacy, acquiescence, afpotus, carried, built, also, ashton, assertive, capital
# - Topic 5: broker, built, capital, campaign, assertive, carrying, capability, acquiescence, account, candidacy
# - Topic 6: carried, broker, built, bedroom, attackcensor, burner, bachmann, calculated, ashton, afpotus
# - Topic 7: broker, built, bangko, capability, carried, acc, assertive, brush, campaign, baited
# - Topic 8: broker, built, bangko, carried, accesspowercontrol, alarming, ballot, bear, assertive, anything
# - Topic 9: aprilmay, carried, banned, admit, campaign, accesspowercontrol, alien, broke, advises, career
# - Topic 10: broker, candidacy, built, assertive, bangko, careless, artificially, administrative, batten, asserted
#
# Time Window 5:
# - Topic 1: brainwash, ashton, breathing, butch, calendar, according, canary, brazil, acting, arranging
# - Topic 2: canary, according, arranging, breathing, butch, brainwash, ashton, calculating, calculated, aw
# - Topic 3: authwh, advance, breathing, bz, calculated, bravogkvt, became, calculating, brazil, annual
# - Topic 4: breathing, according, backwards, brainwash, bravo, bravest, boomerang, barbara, agencycapersonnelremoval, broker
# - Topic 5: brainwash, canary, breathing, butch, altered, broke, according, background, anticapitalistic, adage
# - Topic 6: breathing, brainwash, burned, background, ashton, arranging, aiding, air, backwards, amazon
# - Topic 7: billboard, butch, calendar, brainwash, backwards, breathing, ashton, brad, anne, calculated
# - Topic 8: brainwash, backwards, addressed, ashton, breathing, butch, bachmann, bahamas, burned, asecretplanbyagrouptodosomethingunlawfulorharmful
# - Topic 9: canary, available, asset, appreciated, assassination, brainwash, brady, auto, blowing, bestselling
# - Topic 10: brainwash, calculating, abroad, calculated, backwards, ashton, ask, around, became, aghrc
#
# Time Window 6:
# - Topic 1: arising, bcrc, asecretplanbyagrouptodosomethingunlawfulorharmful, armmsm, attno, barlow, algo, accepting, alias, banktobank
# - Topic 2: becoming, battery, betsy, angered, always, battle, abcde, arise, baker, auditor
# - Topic 3: basis, about, betrays, administration, anderson, angered, battle, attendee, before, bcrc
# - Topic 4: alias, basis, bcrc, anarchy, beth, battleground, another, alignment, actress, are
# - Topic 5: basis, about, ally, berkeley, accepting, betrays, battle, batter, apostate, american
# - Topic 6: bigamist, aghrc, anarchy, bcrc, accepting, beth, alignment, american, anderson, avoiddelay
# - Topic 7: basis, antigod, ally, asst, advice, accurate, afforded, bar, arresting, advancefee
# - Topic 8: basis, another, accepting, bigamist, bcrc, bga, battle, battleground, betsy, baseless
# - Topic 9: another, acting, anarchist, betrayer, artifact, bai, battery, beth, bell, basis
# - Topic 10: berkeley, bigamist, accepting, arresting, basis, american, bcrc, betrays, assassinated, basement
#
# Time Window 7:
# - Topic 1: comey, belong, commsatok, bcrc, broke, congressmanwoman, accumulate, confudtgreen, conquer, contacted
# - Topic 2: commanding, confudtgreen, contain, accumulate, commsatok, broke, alltime, across, alongside, addy
# - Topic 3: across, contacted, comey, confudtgreen, commander, commsatok, apps, broke, australian, accident
# - Topic 4: comey, changing, commsatok, broke, contacted, across, accumulate, belong, congressmanwoman, belt
# - Topic 5: contacted, baltimore, cannotwill, across, card, also, chaos, avoiding, base, balance
# - Topic 6: comey, belong, broke, commsatok, bcrc, connects, conquer, congressmanwoman, accumulate, across
# - Topic 7: commsatok, cant, comey, across, conquer, congressmanwoman, australian, brainwashed, ciardpbr, bridenstine
# - Topic 8: comey, commsatok, broke, conquer, belong, bruce, cant, belize, connects, conflate
# - Topic 9: confudtgreen, comey, bcrc, contacted, commsatok, afraid, brennanclappercarter, americaisbacktoleading, comello, biden
# - Topic 10: comey, breastplate, atl, burundi, confront, connects, alongside, commsatsecrok, connecting, biden
#
# Time Window 8:
# - Topic 1: cnbc, commsoff, carney, cdc, aggravate, bom, bugging, climate, bosnia, allegation
# - Topic 2: bounce, burner, approved, attorney, banco, climate, ancestry, borderwall, batter, acted
# - Topic 3: brass, cnbc, closed, batter, climate, composed, backwards, asecretplanbyagrouptodosomethingunlawfulorharmful, closedloop, canis
# - Topic 4: cnbc, climate, acted, accts, clone, brass, battle, clinic, batter, commitment
# - Topic 5: cnbc, batter, cease, comoros, administrator, assigned, comparecontrast, brass, canis, brightly
# - Topic 6: climate, accts, cnbc, brass, backwards, batter, baseless, alignment, bang, bob
# - Topic 7: composed, climate, cnbc, commitment, acted, comparecontrast, closedloop, clone, brown, batter
# - Topic 8: climate, cnbc, assigned, administrator, composed, commitment, bounce, battle, comparecontrast, company
# - Topic 9: composed, climate, allegation, bosnia, bang, company, batter, cnbc, antiracist, brass
# - Topic 10: climate, clone, batter, acted, company, comparecontrast, commsoff, burner, administrator, cnbc
#
# Time Window 9:
# - Topic 1: chinask, advocate, bandaid, accumulate, charged, blindeye, balslbtczajxk, acooper, charitable, attached
# - Topic 2: charged, chinask, coexist, acooper, bachmann, anticipate, climate, clockwork, closure, boost
# - Topic 3: bury, ample, authorized, cleanup, blackmailed, banned, captcha, botsgoog, charged, clockwork
# - Topic 4: charged, blindeye, chinask, charge, accumulate, checker, coexist, asap, bail, climate
# - Topic 5: charged, bachmann, blindeye, clockwork, chinask, balslbtczajxk, antid, blackout, acooper, coastal
# - Topic 6: balslbtczajxk, chinask, checker, charged, card, brad, california, authentication, chess, coexist
# - Topic 7: blindeye, charged, asecretplanbyagrouptodosomethingunlawfulorharmful, chinask, bh, bachmann, brotherinlaw, block, censor, bringing
# - Topic 8: charged, coexist, blindeye, balslbtczajxk, chinask, blackout, audit, acooper, bachmann, cmbo
# - Topic 9: chinask, charged, cite, black, checker, blindeye, bidder, clock, brotherinlaw, bail
# - Topic 10: chinask, charged, authwh, chaos, andre, blindeye, clockwork, ban, coincide, aggravate
#
# Time Window 10:
# - Topic 1: closedlimited, boooom, assange, clean, comprehend, attempted, antifa, addiction, activeongoing, anomaly
# - Topic 2: clean, boooom, closedlimited, baker, bp, barsoomian, communicate, anita, commit, combatant
# - Topic 3: closedlimited, clean, boooom, commsatfalse, adolf, assemblyman, comprehend, commit, barsoomian, assisthardpush
# - Topic 4: closedlimited, clean, amanda, azerbaijan, comprehend, actblue, certain, commsatfalse, affirm, client
# - Topic 5: abandoning, algorithm, boris, brightly, bom, comms, chem, clickonlog, communicating, called
# - Topic 6: clean, boooom, closedlimited, commsatfalse, anticapitalistic, barsoomian, body, agenda, baker, communicate
# - Topic 7: bosnia, anarchist, barbara, clean, ashton, actblue, closedlimited, buildcode, comm, comprehend
# - Topic 8: closedlimited, clean, commsoff, advisorsskyisfalling, assaulted, autistsanons, commsinstall, comprehend, barsoomian, boooom
# - Topic 9: clean, closedlimited, boooom, baker, certain, accounted, comprehend, avoided, bohr, access
# - Topic 10: closedlimited, clean, body, comprised, assisthardpush, best, assist, baker, ausuk, black
#
# Time Window 11:
# - Topic 1: campaign, chaired, appoint, accuser, began, camouflaged, basement, chairman, attitude, bot
# - Topic 2: called, assist, cannotwill, chaired, began, centrally, austria, battle, accuser, bot
# - Topic 3: called, cannotwill, battle, accomplish, californiaif, assist, arianna, banco, centrally, appoint
# - Topic 4: chaired, attestation, cannotwill, battle, cancel, called, barrwhitaker, accuser, assist, artificially
# - Topic 5: called, ccp, chaired, cannotwill, centrally, accuser, attestation, blackwater, badge, achievement
# - Topic 6: called, battle, accomplish, assist, attestation, cannotwill, affecting, accuser, are, atl
# - Topic 7: called, battle, accomplish, categorized, cannotwill, beam, cen, ccp, candidatepresident, camera
# - Topic 8: called, cannotwill, assist, chaired, among, appears, aheadbehind, capturing, administration, battle
# - Topic 9: cannotwill, called, assist, began, address, beam, ally, battle, attestation, chaired
# - Topic 10: called, battle, cannotwill, centrally, affiliate, ammo, accuser, ccp, chaired, center
#
# Time Window 12:
# - Topic 1: colossian, coincidence, brennanclappercarter, beautiful, accum, awareness, attno, boring, ap, authentication
# - Topic 2: confsilex, coincidence, colossian, authentication, collective, concession, confudtgreen, allvehiclesofdeliveryremoved, built, accusation
# - Topic 3: brennanclappercarter, colossian, coincidence, building, beautiful, attitude, aggressive, cc, coat, aggression
# - Topic 4: concession, coincidence, colossian, action, ben, authentication, accum, beautiful, brennanclappercarter, bronfmans
# - Topic 5: colossian, comprehensive, coincidence, accum, confsilex, confdwwconoffdark, confudtgreen, brings, coi, authentication
# - Topic 6: coincidence, comprehend, beautiful, brennanclappercarter, confsilex, accum, admiration, branded, alq, affect
# - Topic 7: chanting, coincidence, brennanclappercarter, antiabortion, buhr, compromised, cayman, barton, confbeczyy, boygirl
# - Topic 8: built, composed, bridenstine, coincidence, associated, confdwwconoffdark, confsilex, benedict, colossian, collectionnsahomeland
# - Topic 9: colossian, coincidence, boring, chinaqatar, confsilex, beautiful, concession, ap, bat, comprehend
# - Topic 10: coincidence, brennanclappercarter, colossian, accum, ben, coie, beautiful, bat, action, condone
#
# Time Window 13:
# - Topic 1: communicated, complicit, built, bga, accuracy, challenge, construction, adopt, consulting, atnear
# - Topic 2: communicated, complicit, built, atnear, australia, begging, bga, convert, acrosstheboard, campbell
# - Topic 3: communicated, built, convert, bga, approvedmanafort, begging, complicit, acrosstheboard, australia, accuracy
# - Topic 4: compartmentalized, complicit, complex, challenge, approvedmanafort, calm, commschiefs, adopt, aisle, blower
# - Topic 5: communicated, complicit, built, construction, connectionsec, comfy, aggressionslander, buried, bubble, begging
# - Topic 6: communicated, complicit, begging, broker, convert, construction, challenge, atnear, allow, built
# - Topic 7: communicated, complicit, appease, caliber, bdt, containing, brush, challenge, built, campbell
# - Topic 8: communicated, bga, connected, aggrecirdec, anyone, clasndi, broker, broadcast, australia, bc
# - Topic 9: communicated, complicit, built, convert, acrosstheboard, begging, accuracy, bga, conspiratorial, australia
# - Topic 10: communicated, built, actually, brush, brute, bga, almodovar, begging, construction, agree
#
# Time Window 14:
# - Topic 1: choke, checkin, coerced, account, acted, bot, check, acooper, barbara, boltons
# - Topic 2: checkin, coerced, backup, barbara, agency, assistset, alike, caution, calc, acooper
# - Topic 3: checkin, choke, clone, bloodline, cdcwho, asleep, antiabortion, arent, backup, burden
# - Topic 4: checkin, bloodline, backup, choke, coerced, clone, attached, antisoviet, alwaleed, acooper
# - Topic 5: checkin, coerced, choke, acooper, account, barbara, clickonlog, bloodline, backup, china
# - Topic 6: choke, childrens, checkin, burden, assistset, antifacom, barbara, brown, bloodline, brainwashed
# - Topic 7: asserted, bloodline, choke, antifacom, child, acooper, between, christian, activated, assistant
# - Topic 8: checkin, choke, acooper, barbara, china, coerced, alexandra, bod, blower, blamed
# - Topic 9: checkin, blower, bill, clickonlog, arbiter, age, closeproximity, blamed, breakin, choke
# - Topic 10: checkin, choke, bloodline, coerced, bind, clone, account, backup, azerbaijan, closer
#
# Time Window 15:
# - Topic 1: clayton, clasq, close, boring, competition, chikd, balslbtczajxk, be, barrdurham, ago
# - Topic 2: bit, adolf, chagaris, clownsprivate, action, annie, bridge, compassion, block, allows
# - Topic 3: barry, coming, cfr, close, anomaly, bugged, ceased, antilles, boring, closedlimited
# - Topic 4: clayton, close, bounce, abedin, changed, barrdurham, anytime, brennans, commenttake, accident
# - Topic 5: clayton, close, antiamerican, barcelona, accelerated, clickonpreview, appointed, commoninterest, chip, assign
# - Topic 6: close, clayton, competition, accustomed, boring, action, barrdurham, be, attacking, adopt
# - Topic 7: click, close, benghazi, barrdurham, clayton, christie, annie, commsatok, audio, aggravate
# - Topic 8: aggression, aghrc, close, announcement, appreciated, budget, assetagent, commenttake, clayton, abedin
# - Topic 9: clayton, close, be, applied, boring, competition, clevel, beacon, allen, advantage
# - Topic 10: clayton, boring, close, accustomed, barrdurham, comms, be, anytime, commenttake, comb
#
# Time Window 16:
# - Topic 1: barter, berman, ac, arrange, adapt, await, barry, affirm, attendance, armor
# - Topic 2: aside, arm, amy, americaisbacktoleading, affirmation, affiliation, anarchy, anon, antipotus, arena
# - Topic 3: barack, allpower, ac, arrange, antigay, begun, arkansas, assange, barrage, bed
# - Topic 4: apparatus, arrange, advocate, allison, barack, barter, armmsm, bchrc, alaskan, ac
# - Topic 5: barack, barter, announcing, arrange, alexandra, barrel, accessed, allpower, belgium, berman
# - Topic 6: barack, attendance, berman, arrange, barter, belgium, abrams, ability, bell, bar
# - Topic 7: barack, barter, begun, askyourselfiftheusgdpisgreaterthanthetotalofallotherscombinedgwhichallowsustonegotiatefromapositionofstrengthwhywouldpreviouspresidentsknowinglyunequallydistributeamericaswealthawaybymakingunbalancedtradedeals, amended, benghazi, accurately, berman, apple, agree
# - Topic 8: anticipate, barack, barter, berman, arrange, arabia, abrams, actively, barrdurhamhuber, ac
# - Topic 9: barack, barter, announcing, barrdurham, bell, asktheq, armmsm, anticipate, abrams, bahrain
# - Topic 10: barack, askyourselfiftheusgdpisgreaterthanthetotalofallotherscombinedgwhichallowsustonegotiatefromapositionofstrengthwhywouldpreviouspresidentsknowinglyunequallydistributeamericaswealthawaybymakingunbalancedtradedeals, airport, becker, az, arrange, believer, barter, announcing, agdag
#
# Time Window 17:
# - Topic 1: book, barr, affect, budget, armmsm, bought, awe, brightly, beautiful, approvedmanafort
# - Topic 2: book, bought, activatecodezjg, beauty, bcll, authorization, activating, awe, asf, absolutely
# - Topic 3: book, bought, austria, awe, accord, british, admitted, bronfman, beast, armmsm
# - Topic 4: bought, book, awe, acceptance, asf, accord, asia, bcll, ban, antifa
# - Topic 5: awe, bought, ag, blockade, accord, akin, avoiddelay, accumulate, bcll, bailouts
# - Topic 6: book, awaiting, british, adoption, armmsm, bought, ag, blockbyblock, building, asf
# - Topic 7: book, bought, building, antifa, awe, armenia, attend, bocsbonocsnobo, are, authenticity
# - Topic 8: book, bought, awe, building, accord, armmsm, alterchange, acceptance, asf, averted
# - Topic 9: book, bought, brief, belgium, buckle, ascension, authorization, accord, british, acceptance
# - Topic 10: book, awe, broadcast, averted, borderwall, armmsm, asf, building, atkinson, avoiddelay
#
# Time Window 18:
# - Topic 1: cheatin, capy, accuser, china, arena, chch, attackwarning, april, attitude, bind
# - Topic 2: carryon, capy, becomes, attitude, affair, according, authzgp, better, automatically, china
# - Topic 3: capy, authzgp, activecommence, battling, askyourselfasimplequestionwhy, bolton, charging, charitable, childrenpeople, carryon
# - Topic 4: capy, becomes, challenged, carryon, channel, authzgp, chicago, carlin, china, awanpakistani
# - Topic 5: belgium, capy, becomes, accuracy, asking, carryon, addressed, beverly, according, afa
# - Topic 6: capy, authzgp, carl, carryon, bdtfalse, becomes, broadcast, carlin, carrier, better
# - Topic 7: capy, carryon, becomes, china, bad, barr, breathing, archive, authzgp, beg
# - Topic 8: capy, becomes, china, carryon, charitable, afa, according, alcohol, accuser, authzgp
# - Topic 9: capy, becomes, according, absurd, china, carryon, attitude, ashamed, chinabuilding, checker
# - Topic 10: carryon, china, capy, carl, challenged, bond, battle, adam, arena, awanpakistani
#
# Time Window 19:
# - Topic 1: caucus, autotruth, ammunition, castro, cdef, cancerbaby, anonspatriots, april, arguing, chris
# - Topic 2: castro, arranging, acooper, childrenpeople, affirm, chris, belonging, asks, caution, caliber
# - Topic 3: castro, betraying, chris, cdef, accesspowercontrol, chemical, alexandra, bachmann, annie, affiliated
# - Topic 4: categorized, asks, anytime, begging, capability, checkmate, altered, amend, capturekill, adult
# - Topic 5: castro, cdef, betraying, authentication, castlerock, chris, child, accesspowercontrol, anderson, arranging
# - Topic 6: cdef, castro, ai, bachmann, blockobstruct, betraying, ausuk, authentication, appreciation, chem
# - Topic 7: cheap, castro, accum, bachmann, chose, accesspowercontrol, biggest, causing, cdef, benefit
# - Topic 8: castro, cdef, betraying, chem, boxer, bachmann, caucus, border, accesspowercontrol, accum
# - Topic 9: castro, betraying, chris, anoint, attire, authentication, accesspowercontrol, centrist, castlearrivalgood, childrenpeople
# - Topic 10: castro, cdef, anoint, chris, blockobstruct, anderson, attire, border, bh, away
#
# Time Window 20:
# - Topic 1: brussels, barrdurhamhuber, attendee, accesscensorshiptracking, bunch, aiding, assist, admr, brush, att
# - Topic 2: brussels, carlo, aaron, brzezinski, boris, boy, advancefee, bros, anita, attendee
# - Topic 3: brussels, accesscensorshiptracking, americawassystematicallybeingweakened, capture, bunch, assist, car, carlo, achieve, captain
# - Topic 4: brussels, carlo, capability, albeit, attendee, barsoomian, assembled, belonging, captain, assist
# - Topic 5: bunch, bail, activecommence, alphabet, bird, anita, candidacy, account, absurd, captured
# - Topic 6: barrdurhamhuber, carlo, americawassystematicallybeingweakened, asks, bunch, appeal, brussels, appoints, bing, alyssa
# - Topic 7: brussels, bunch, account, barrdurhamhuber, attestation, build, candidacy, carlo, arabia, boat
# - Topic 8: brussels, barrdurhamhuber, bunch, accesscensorshiptracking, boalexander, assist, bite, alive, build, attendee
# - Topic 9: anytime, brussels, apply, barrdurhamhuber, bunch, carlo, asks, account, carnal, aiding
# - Topic 10: carey, cancelled, candidacy, capture, asstd, brussels, assist, boooom, activecommence, breakin
#
# Time Window 21:
# - Topic 1: already, caucus, cafferty, but, bauman, branch, afghanistan, accessible, buz, betrayal
# - Topic 2: accessible, case, alike, assdnymw, but, acct, apostolic, algorithm, censor, beforehand
# - Topic 3: backstopped, captain, backgroundsoroshusseinhrcmsmsocialmhollywood, administrator, broader, blessing, beforeafter, arriving, cage, activeduty
# - Topic 4: bauman, cafferty, accessible, but, associatesassistants, bergman, archbishop, attackcensor, attacking, bear
# - Topic 5: caucus, acct, bauman, accessible, banremove, censored, bcll, alert, binney, already
# - Topic 6: but, abuse, bcll, case, aprilmay, bay, backgroundsoroshusseinhrcmsmsocialmhollywood, bissau, admr, activeongoing
# - Topic 7: but, bauman, censor, attackcensor, believer, caught, aircraft, cataloging, cafferty, bdt
# - Topic 8: celestial, attackcensor, but, cdef, believer, blood, appear, cannotwill, belongs, armextension
# - Topic 9: acooper, but, catalog, benin, attackcensor, activeongoing, alert, asksed, asap, batten
# - Topic 10: but, cafferty, bauman, accessible, censor, amendment, ashton, attackcensor, bear, by
#
# Time Window 22:
# - Topic 1: crew, chat, crumb, actionable, boy, brought, additionally, creleases, defeating, deceiving
# - Topic 2: censorship, crew, authzgp, client, attack, city, citizenship, century, defeating, bond
# - Topic 3: crew, actionable, chat, against, begun, blackhispanic, bader, boy, brought, defeating
# - Topic 4: chat, crumb, crew, chinanonpublic, actionable, boy, change, defeating, brought, arrange
# - Topic 5: crumb, alleged, declas, brzezinski, defeating, deceiving, crew, declares, comb, brought
# - Topic 6: crew, crumb, actionable, chat, boy, deal, declas, crucial, chose, defeating
# - Topic 7: chat, crumb, aimed, can, comb, actionable, attended, appoint, circulates, aggressively
# - Topic 8: crew, crumb, chat, actionable, brought, declares, declas, defeating, additionally, algos
# - Topic 9: crew, crumb, declared, declares, apache, defection, brought, comb, blame, alarm
# - Topic 10: crumb, crew, additionally, crosharing, actionable, bd, defection, absolutely, adopting, chopper
#
# Time Window 23:
# - Topic 1: active, chalupa, court, countdown, cybersecurity, asking, bastest, americaeconomy, dca, bo
# - Topic 2: countdown, chalupa, court, adj, datesweek, chagaris, dean, cannotwill, brave, active
# - Topic 3: court, countdown, darpa, chalupa, assisthardpush, blockobstruct, bo, dean, active, caution
# - Topic 4: brave, darpa, crane, anniversary, allvehiclesofdeliveryremoved, counterintelligence, corp, construction, alltime, blood
# - Topic 5: countdown, chalupa, court, bo, borderwall, darpagoog, active, chinarussia, apart, activated
# - Topic 6: chalupa, adj, datesweek, balance, combination, court, countdown, darpa, courtroom, agree
# - Topic 7: commschiefs, captured, chris, communicate, clue, court, barrel, da, attestation, apparatus
# - Topic 8: chalupa, court, active, countdown, cybersecurity, comm, dca, bo, americaeconomy, bastest
# - Topic 9: david, chalupa, countdown, carnal, caliber, bo, again, counterevents, anarchy, calm
# - Topic 10: court, data, baltimore, affecting, cleaned, cfr, cen, buz, colony, cybersecurity

# %%
def interpret_topics(relevant_topics_per_window):
    common_crime_terms = set()  # Store common crime-related terms across all time windows

    # Iterate through each time window and interpret the topics
    for window, topics in relevant_topics_per_window.items():
        print(f"Time Window {window}:")
        crime_related_topics = []  # Store crime-related topics for the current time window

        # Print and analyze each topic
        for topic, top_words in topics.items():
            print(f"- {topic}: {', '.join(top_words)}")
            crime_terms = [word for word in top_words]
            crime_related_topics.append(topic)
            common_crime_terms.update(crime_terms)

        # Print crime-related topics for the current time window
        if crime_related_topics:
            for topic in crime_related_topics:
                print(f"  - {topic}")

        print()

    # Print common crime-related terms across all time windows
    if common_crime_terms:
        print("Common Crime-related Terms:")
        print(', '.join(common_crime_terms))
    else:
        print("No common crime-related terms found across all time windows")

# Call the function to interpret topics and identify common crime-related terms
interpret_topics(relevant_topics_per_window)
# Out:
# Time Window 1:
# - Topic 1: denies, admissible, chinarussia, compared, advise, clarification, calendar, crystal, blood, dem
# - Topic 2: calendar, disclosuresreports, disaster, deleteinstall, demean, dilute, controlling, countered, disclosing, denies
# - Topic 3: deleteinstall, clue, agent, denies, calendar, disaster, actspub, brush, disclosing, disclosuresreports
# - Topic 4: deleteinstall, denies, calendar, clue, actspub, disaster, demean, disclosuresreports, aggressive, conceal
# - Topic 5: denies, actspub, disguised, alwaleed, aggressive, deleteinstall, bxzja, brush, administrative, blizzard
# - Topic 6: deleteinstall, disruption, denies, actspub, disaster, brush, disclosuresreports, dilute, disclosing, calendar
# - Topic 7: alqaradawi, active, aag, buckle, customized, at, discovered, alarm, appellate, cripple
# - Topic 8: deleteinstall, denies, disaster, actspub, collins, calendar, dem, betterment, borderwall, bought
# - Topic 9: blm, disconcerting, actspub, denies, demean, advocate, clickonpreview, directly, acooper, competitor
# - Topic 10: actspub, deleteinstall, demean, disclosing, calendar, cult, commsinstall, blm, asecretplanbyagrouptodosomethingunlawfulorharmful, clue
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 2:
# - Topic 1: billion, brand, blank, adopting, boom, amid, aurn, balance, afford, algorithm
# - Topic 2: boom, ally, always, babcs, altitude, arrested, bahrain, billion, awans, antisessions
# - Topic 3: accepting, bite, approvedpage, alt, america, blank, at, brand, boom, billion
# - Topic 4: billion, bishop, blank, attach, approvedpage, absolute, associatesassistants, animal, apple, bio
# - Topic 5: brand, billion, accepting, blank, aug, boom, announced, antihydroxychloroquine, assembly, advisory
# - Topic 6: anarchist, anchor, address, attackwarning, blank, announced, ball, actspub, accurately, adopt
# - Topic 7: balance, billion, blank, attach, apple, against, boom, aggimagefailure, activeduty, accessed
# - Topic 8: billion, boukaus, approvedpage, branded, almost, bit, borger, attach, accepting, botsgoog
# - Topic 9: billion, attachment, blank, blmcom, balance, apple, apparatus, agent, asst, bignewsweek
# - Topic 10: billion, asst, brand, available, boukaus, approvedpage, borger, apple, aj, agenda
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 3:
# - Topic 1: belong, categorizedlabeled, castleonline, authored, carlo, appreciation, cheating, begging, attire, accomplish
# - Topic 2: carlo, categorizedlabeled, blanket, choose, attire, castleonline, batten, been, architect, cell
# - Topic 3: carefully, brightly, cfi, categorizedlabeled, accomplish, below, blake, appeal, catch, awandwspaki
# - Topic 4: aka, amongst, betterment, aiding, cayman, anons, benavides, belong, ahead, carle
# - Topic 5: attire, carlo, choose, accomplish, categorizedlabeled, chance, atmosphere, authored, accumulate, cheap
# - Topic 6: carlo, chance, accumulate, bidenchina, ascertained, bigger, ascension, cheap, architect, authored
# - Topic 7: carlo, car, categorizedlabeled, cheap, apostolic, activist, adv, accomplish, authored, chairceovpremoval
# - Topic 8: carlo, choose, categorizedlabeled, accumulate, activist, chance, belong, castleonline, castlerock, checkinzdestfc
# - Topic 9: categorizedlabeled, authored, carlo, cheap, cheating, agency, charged, chagaris, begging, amount
# - Topic 10: bull, categorizedlabeled, channel, ahead, below, checkinzdestfc, before, begging, castleonline, blake
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 4:
# - Topic 1: broker, ashton, built, bangko, assertive, bloodstream, cap, amid, cancer, calculated
# - Topic 2: broker, anticipated, acquiescence, acct, antiamerica, are, admit, bangko, brown, arrival
# - Topic 3: carried, broker, accesspowercontrol, campaign, assertive, built, capability, cap, bigamist, barrdurham
# - Topic 4: broker, candidacy, acquiescence, afpotus, carried, built, also, ashton, assertive, capital
# - Topic 5: broker, built, capital, campaign, assertive, carrying, capability, acquiescence, account, candidacy
# - Topic 6: carried, broker, built, bedroom, attackcensor, burner, bachmann, calculated, ashton, afpotus
# - Topic 7: broker, built, bangko, capability, carried, acc, assertive, brush, campaign, baited
# - Topic 8: broker, built, bangko, carried, accesspowercontrol, alarming, ballot, bear, assertive, anything
# - Topic 9: aprilmay, carried, banned, admit, campaign, accesspowercontrol, alien, broke, advises, career
# - Topic 10: broker, candidacy, built, assertive, bangko, careless, artificially, administrative, batten, asserted
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 5:
# - Topic 1: brainwash, ashton, breathing, butch, calendar, according, canary, brazil, acting, arranging
# - Topic 2: canary, according, arranging, breathing, butch, brainwash, ashton, calculating, calculated, aw
# - Topic 3: authwh, advance, breathing, bz, calculated, bravogkvt, became, calculating, brazil, annual
# - Topic 4: breathing, according, backwards, brainwash, bravo, bravest, boomerang, barbara, agencycapersonnelremoval, broker
# - Topic 5: brainwash, canary, breathing, butch, altered, broke, according, background, anticapitalistic, adage
# - Topic 6: breathing, brainwash, burned, background, ashton, arranging, aiding, air, backwards, amazon
# - Topic 7: billboard, butch, calendar, brainwash, backwards, breathing, ashton, brad, anne, calculated
# - Topic 8: brainwash, backwards, addressed, ashton, breathing, butch, bachmann, bahamas, burned, asecretplanbyagrouptodosomethingunlawfulorharmful
# - Topic 9: canary, available, asset, appreciated, assassination, brainwash, brady, auto, blowing, bestselling
# - Topic 10: brainwash, calculating, abroad, calculated, backwards, ashton, ask, around, became, aghrc
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 6:
# - Topic 1: arising, bcrc, asecretplanbyagrouptodosomethingunlawfulorharmful, armmsm, attno, barlow, algo, accepting, alias, banktobank
# - Topic 2: becoming, battery, betsy, angered, always, battle, abcde, arise, baker, auditor
# - Topic 3: basis, about, betrays, administration, anderson, angered, battle, attendee, before, bcrc
# - Topic 4: alias, basis, bcrc, anarchy, beth, battleground, another, alignment, actress, are
# - Topic 5: basis, about, ally, berkeley, accepting, betrays, battle, batter, apostate, american
# - Topic 6: bigamist, aghrc, anarchy, bcrc, accepting, beth, alignment, american, anderson, avoiddelay
# - Topic 7: basis, antigod, ally, asst, advice, accurate, afforded, bar, arresting, advancefee
# - Topic 8: basis, another, accepting, bigamist, bcrc, bga, battle, battleground, betsy, baseless
# - Topic 9: another, acting, anarchist, betrayer, artifact, bai, battery, beth, bell, basis
# - Topic 10: berkeley, bigamist, accepting, arresting, basis, american, bcrc, betrays, assassinated, basement
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 7:
# - Topic 1: comey, belong, commsatok, bcrc, broke, congressmanwoman, accumulate, confudtgreen, conquer, contacted
# - Topic 2: commanding, confudtgreen, contain, accumulate, commsatok, broke, alltime, across, alongside, addy
# - Topic 3: across, contacted, comey, confudtgreen, commander, commsatok, apps, broke, australian, accident
# - Topic 4: comey, changing, commsatok, broke, contacted, across, accumulate, belong, congressmanwoman, belt
# - Topic 5: contacted, baltimore, cannotwill, across, card, also, chaos, avoiding, base, balance
# - Topic 6: comey, belong, broke, commsatok, bcrc, connects, conquer, congressmanwoman, accumulate, across
# - Topic 7: commsatok, cant, comey, across, conquer, congressmanwoman, australian, brainwashed, ciardpbr, bridenstine
# - Topic 8: comey, commsatok, broke, conquer, belong, bruce, cant, belize, connects, conflate
# - Topic 9: confudtgreen, comey, bcrc, contacted, commsatok, afraid, brennanclappercarter, americaisbacktoleading, comello, biden
# - Topic 10: comey, breastplate, atl, burundi, confront, connects, alongside, commsatsecrok, connecting, biden
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 8:
# - Topic 1: cnbc, commsoff, carney, cdc, aggravate, bom, bugging, climate, bosnia, allegation
# - Topic 2: bounce, burner, approved, attorney, banco, climate, ancestry, borderwall, batter, acted
# - Topic 3: brass, cnbc, closed, batter, climate, composed, backwards, asecretplanbyagrouptodosomethingunlawfulorharmful, closedloop, canis
# - Topic 4: cnbc, climate, acted, accts, clone, brass, battle, clinic, batter, commitment
# - Topic 5: cnbc, batter, cease, comoros, administrator, assigned, comparecontrast, brass, canis, brightly
# - Topic 6: climate, accts, cnbc, brass, backwards, batter, baseless, alignment, bang, bob
# - Topic 7: composed, climate, cnbc, commitment, acted, comparecontrast, closedloop, clone, brown, batter
# - Topic 8: climate, cnbc, assigned, administrator, composed, commitment, bounce, battle, comparecontrast, company
# - Topic 9: composed, climate, allegation, bosnia, bang, company, batter, cnbc, antiracist, brass
# - Topic 10: climate, clone, batter, acted, company, comparecontrast, commsoff, burner, administrator, cnbc
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 9:
# - Topic 1: chinask, advocate, bandaid, accumulate, charged, blindeye, balslbtczajxk, acooper, charitable, attached
# - Topic 2: charged, chinask, coexist, acooper, bachmann, anticipate, climate, clockwork, closure, boost
# - Topic 3: bury, ample, authorized, cleanup, blackmailed, banned, captcha, botsgoog, charged, clockwork
# - Topic 4: charged, blindeye, chinask, charge, accumulate, checker, coexist, asap, bail, climate
# - Topic 5: charged, bachmann, blindeye, clockwork, chinask, balslbtczajxk, antid, blackout, acooper, coastal
# - Topic 6: balslbtczajxk, chinask, checker, charged, card, brad, california, authentication, chess, coexist
# - Topic 7: blindeye, charged, asecretplanbyagrouptodosomethingunlawfulorharmful, chinask, bh, bachmann, brotherinlaw, block, censor, bringing
# - Topic 8: charged, coexist, blindeye, balslbtczajxk, chinask, blackout, audit, acooper, bachmann, cmbo
# - Topic 9: chinask, charged, cite, black, checker, blindeye, bidder, clock, brotherinlaw, bail
# - Topic 10: chinask, charged, authwh, chaos, andre, blindeye, clockwork, ban, coincide, aggravate
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 10:
# - Topic 1: closedlimited, boooom, assange, clean, comprehend, attempted, antifa, addiction, activeongoing, anomaly
# - Topic 2: clean, boooom, closedlimited, baker, bp, barsoomian, communicate, anita, commit, combatant
# - Topic 3: closedlimited, clean, boooom, commsatfalse, adolf, assemblyman, comprehend, commit, barsoomian, assisthardpush
# - Topic 4: closedlimited, clean, amanda, azerbaijan, comprehend, actblue, certain, commsatfalse, affirm, client
# - Topic 5: abandoning, algorithm, boris, brightly, bom, comms, chem, clickonlog, communicating, called
# - Topic 6: clean, boooom, closedlimited, commsatfalse, anticapitalistic, barsoomian, body, agenda, baker, communicate
# - Topic 7: bosnia, anarchist, barbara, clean, ashton, actblue, closedlimited, buildcode, comm, comprehend
# - Topic 8: closedlimited, clean, commsoff, advisorsskyisfalling, assaulted, autistsanons, commsinstall, comprehend, barsoomian, boooom
# - Topic 9: clean, closedlimited, boooom, baker, certain, accounted, comprehend, avoided, bohr, access
# - Topic 10: closedlimited, clean, body, comprised, assisthardpush, best, assist, baker, ausuk, black
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 11:
# - Topic 1: campaign, chaired, appoint, accuser, began, camouflaged, basement, chairman, attitude, bot
# - Topic 2: called, assist, cannotwill, chaired, began, centrally, austria, battle, accuser, bot
# - Topic 3: called, cannotwill, battle, accomplish, californiaif, assist, arianna, banco, centrally, appoint
# - Topic 4: chaired, attestation, cannotwill, battle, cancel, called, barrwhitaker, accuser, assist, artificially
# - Topic 5: called, ccp, chaired, cannotwill, centrally, accuser, attestation, blackwater, badge, achievement
# - Topic 6: called, battle, accomplish, assist, attestation, cannotwill, affecting, accuser, are, atl
# - Topic 7: called, battle, accomplish, categorized, cannotwill, beam, cen, ccp, candidatepresident, camera
# - Topic 8: called, cannotwill, assist, chaired, among, appears, aheadbehind, capturing, administration, battle
# - Topic 9: cannotwill, called, assist, began, address, beam, ally, battle, attestation, chaired
# - Topic 10: called, battle, cannotwill, centrally, affiliate, ammo, accuser, ccp, chaired, center
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 12:
# - Topic 1: colossian, coincidence, brennanclappercarter, beautiful, accum, awareness, attno, boring, ap, authentication
# - Topic 2: confsilex, coincidence, colossian, authentication, collective, concession, confudtgreen, allvehiclesofdeliveryremoved, built, accusation
# - Topic 3: brennanclappercarter, colossian, coincidence, building, beautiful, attitude, aggressive, cc, coat, aggression
# - Topic 4: concession, coincidence, colossian, action, ben, authentication, accum, beautiful, brennanclappercarter, bronfmans
# - Topic 5: colossian, comprehensive, coincidence, accum, confsilex, confdwwconoffdark, confudtgreen, brings, coi, authentication
# - Topic 6: coincidence, comprehend, beautiful, brennanclappercarter, confsilex, accum, admiration, branded, alq, affect
# - Topic 7: chanting, coincidence, brennanclappercarter, antiabortion, buhr, compromised, cayman, barton, confbeczyy, boygirl
# - Topic 8: built, composed, bridenstine, coincidence, associated, confdwwconoffdark, confsilex, benedict, colossian, collectionnsahomeland
# - Topic 9: colossian, coincidence, boring, chinaqatar, confsilex, beautiful, concession, ap, bat, comprehend
# - Topic 10: coincidence, brennanclappercarter, colossian, accum, ben, coie, beautiful, bat, action, condone
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 13:
# - Topic 1: communicated, complicit, built, bga, accuracy, challenge, construction, adopt, consulting, atnear
# - Topic 2: communicated, complicit, built, atnear, australia, begging, bga, convert, acrosstheboard, campbell
# - Topic 3: communicated, built, convert, bga, approvedmanafort, begging, complicit, acrosstheboard, australia, accuracy
# - Topic 4: compartmentalized, complicit, complex, challenge, approvedmanafort, calm, commschiefs, adopt, aisle, blower
# - Topic 5: communicated, complicit, built, construction, connectionsec, comfy, aggressionslander, buried, bubble, begging
# - Topic 6: communicated, complicit, begging, broker, convert, construction, challenge, atnear, allow, built
# - Topic 7: communicated, complicit, appease, caliber, bdt, containing, brush, challenge, built, campbell
# - Topic 8: communicated, bga, connected, aggrecirdec, anyone, clasndi, broker, broadcast, australia, bc
# - Topic 9: communicated, complicit, built, convert, acrosstheboard, begging, accuracy, bga, conspiratorial, australia
# - Topic 10: communicated, built, actually, brush, brute, bga, almodovar, begging, construction, agree
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 14:
# - Topic 1: choke, checkin, coerced, account, acted, bot, check, acooper, barbara, boltons
# - Topic 2: checkin, coerced, backup, barbara, agency, assistset, alike, caution, calc, acooper
# - Topic 3: checkin, choke, clone, bloodline, cdcwho, asleep, antiabortion, arent, backup, burden
# - Topic 4: checkin, bloodline, backup, choke, coerced, clone, attached, antisoviet, alwaleed, acooper
# - Topic 5: checkin, coerced, choke, acooper, account, barbara, clickonlog, bloodline, backup, china
# - Topic 6: choke, childrens, checkin, burden, assistset, antifacom, barbara, brown, bloodline, brainwashed
# - Topic 7: asserted, bloodline, choke, antifacom, child, acooper, between, christian, activated, assistant
# - Topic 8: checkin, choke, acooper, barbara, china, coerced, alexandra, bod, blower, blamed
# - Topic 9: checkin, blower, bill, clickonlog, arbiter, age, closeproximity, blamed, breakin, choke
# - Topic 10: checkin, choke, bloodline, coerced, bind, clone, account, backup, azerbaijan, closer
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 15:
# - Topic 1: clayton, clasq, close, boring, competition, chikd, balslbtczajxk, be, barrdurham, ago
# - Topic 2: bit, adolf, chagaris, clownsprivate, action, annie, bridge, compassion, block, allows
# - Topic 3: barry, coming, cfr, close, anomaly, bugged, ceased, antilles, boring, closedlimited
# - Topic 4: clayton, close, bounce, abedin, changed, barrdurham, anytime, brennans, commenttake, accident
# - Topic 5: clayton, close, antiamerican, barcelona, accelerated, clickonpreview, appointed, commoninterest, chip, assign
# - Topic 6: close, clayton, competition, accustomed, boring, action, barrdurham, be, attacking, adopt
# - Topic 7: click, close, benghazi, barrdurham, clayton, christie, annie, commsatok, audio, aggravate
# - Topic 8: aggression, aghrc, close, announcement, appreciated, budget, assetagent, commenttake, clayton, abedin
# - Topic 9: clayton, close, be, applied, boring, competition, clevel, beacon, allen, advantage
# - Topic 10: clayton, boring, close, accustomed, barrdurham, comms, be, anytime, commenttake, comb
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 16:
# - Topic 1: barter, berman, ac, arrange, adapt, await, barry, affirm, attendance, armor
# - Topic 2: aside, arm, amy, americaisbacktoleading, affirmation, affiliation, anarchy, anon, antipotus, arena
# - Topic 3: barack, allpower, ac, arrange, antigay, begun, arkansas, assange, barrage, bed
# - Topic 4: apparatus, arrange, advocate, allison, barack, barter, armmsm, bchrc, alaskan, ac
# - Topic 5: barack, barter, announcing, arrange, alexandra, barrel, accessed, allpower, belgium, berman
# - Topic 6: barack, attendance, berman, arrange, barter, belgium, abrams, ability, bell, bar
# - Topic 7: barack, barter, begun, askyourselfiftheusgdpisgreaterthanthetotalofallotherscombinedgwhichallowsustonegotiatefromapositionofstrengthwhywouldpreviouspresidentsknowinglyunequallydistributeamericaswealthawaybymakingunbalancedtradedeals, amended, benghazi, accurately, berman, apple, agree
# - Topic 8: anticipate, barack, barter, berman, arrange, arabia, abrams, actively, barrdurhamhuber, ac
# - Topic 9: barack, barter, announcing, barrdurham, bell, asktheq, armmsm, anticipate, abrams, bahrain
# - Topic 10: barack, askyourselfiftheusgdpisgreaterthanthetotalofallotherscombinedgwhichallowsustonegotiatefromapositionofstrengthwhywouldpreviouspresidentsknowinglyunequallydistributeamericaswealthawaybymakingunbalancedtradedeals, airport, becker, az, arrange, believer, barter, announcing, agdag
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 17:
# - Topic 1: book, barr, affect, budget, armmsm, bought, awe, brightly, beautiful, approvedmanafort
# - Topic 2: book, bought, activatecodezjg, beauty, bcll, authorization, activating, awe, asf, absolutely
# - Topic 3: book, bought, austria, awe, accord, british, admitted, bronfman, beast, armmsm
# - Topic 4: bought, book, awe, acceptance, asf, accord, asia, bcll, ban, antifa
# - Topic 5: awe, bought, ag, blockade, accord, akin, avoiddelay, accumulate, bcll, bailouts
# - Topic 6: book, awaiting, british, adoption, armmsm, bought, ag, blockbyblock, building, asf
# - Topic 7: book, bought, building, antifa, awe, armenia, attend, bocsbonocsnobo, are, authenticity
# - Topic 8: book, bought, awe, building, accord, armmsm, alterchange, acceptance, asf, averted
# - Topic 9: book, bought, brief, belgium, buckle, ascension, authorization, accord, british, acceptance
# - Topic 10: book, awe, broadcast, averted, borderwall, armmsm, asf, building, atkinson, avoiddelay
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 18:
# - Topic 1: cheatin, capy, accuser, china, arena, chch, attackwarning, april, attitude, bind
# - Topic 2: carryon, capy, becomes, attitude, affair, according, authzgp, better, automatically, china
# - Topic 3: capy, authzgp, activecommence, battling, askyourselfasimplequestionwhy, bolton, charging, charitable, childrenpeople, carryon
# - Topic 4: capy, becomes, challenged, carryon, channel, authzgp, chicago, carlin, china, awanpakistani
# - Topic 5: belgium, capy, becomes, accuracy, asking, carryon, addressed, beverly, according, afa
# - Topic 6: capy, authzgp, carl, carryon, bdtfalse, becomes, broadcast, carlin, carrier, better
# - Topic 7: capy, carryon, becomes, china, bad, barr, breathing, archive, authzgp, beg
# - Topic 8: capy, becomes, china, carryon, charitable, afa, according, alcohol, accuser, authzgp
# - Topic 9: capy, becomes, according, absurd, china, carryon, attitude, ashamed, chinabuilding, checker
# - Topic 10: carryon, china, capy, carl, challenged, bond, battle, adam, arena, awanpakistani
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 19:
# - Topic 1: caucus, autotruth, ammunition, castro, cdef, cancerbaby, anonspatriots, april, arguing, chris
# - Topic 2: castro, arranging, acooper, childrenpeople, affirm, chris, belonging, asks, caution, caliber
# - Topic 3: castro, betraying, chris, cdef, accesspowercontrol, chemical, alexandra, bachmann, annie, affiliated
# - Topic 4: categorized, asks, anytime, begging, capability, checkmate, altered, amend, capturekill, adult
# - Topic 5: castro, cdef, betraying, authentication, castlerock, chris, child, accesspowercontrol, anderson, arranging
# - Topic 6: cdef, castro, ai, bachmann, blockobstruct, betraying, ausuk, authentication, appreciation, chem
# - Topic 7: cheap, castro, accum, bachmann, chose, accesspowercontrol, biggest, causing, cdef, benefit
# - Topic 8: castro, cdef, betraying, chem, boxer, bachmann, caucus, border, accesspowercontrol, accum
# - Topic 9: castro, betraying, chris, anoint, attire, authentication, accesspowercontrol, centrist, castlearrivalgood, childrenpeople
# - Topic 10: castro, cdef, anoint, chris, blockobstruct, anderson, attire, border, bh, away
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 20:
# - Topic 1: brussels, barrdurhamhuber, attendee, accesscensorshiptracking, bunch, aiding, assist, admr, brush, att
# - Topic 2: brussels, carlo, aaron, brzezinski, boris, boy, advancefee, bros, anita, attendee
# - Topic 3: brussels, accesscensorshiptracking, americawassystematicallybeingweakened, capture, bunch, assist, car, carlo, achieve, captain
# - Topic 4: brussels, carlo, capability, albeit, attendee, barsoomian, assembled, belonging, captain, assist
# - Topic 5: bunch, bail, activecommence, alphabet, bird, anita, candidacy, account, absurd, captured
# - Topic 6: barrdurhamhuber, carlo, americawassystematicallybeingweakened, asks, bunch, appeal, brussels, appoints, bing, alyssa
# - Topic 7: brussels, bunch, account, barrdurhamhuber, attestation, build, candidacy, carlo, arabia, boat
# - Topic 8: brussels, barrdurhamhuber, bunch, accesscensorshiptracking, boalexander, assist, bite, alive, build, attendee
# - Topic 9: anytime, brussels, apply, barrdurhamhuber, bunch, carlo, asks, account, carnal, aiding
# - Topic 10: carey, cancelled, candidacy, capture, asstd, brussels, assist, boooom, activecommence, breakin
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 21:
# - Topic 1: already, caucus, cafferty, but, bauman, branch, afghanistan, accessible, buz, betrayal
# - Topic 2: accessible, case, alike, assdnymw, but, acct, apostolic, algorithm, censor, beforehand
# - Topic 3: backstopped, captain, backgroundsoroshusseinhrcmsmsocialmhollywood, administrator, broader, blessing, beforeafter, arriving, cage, activeduty
# - Topic 4: bauman, cafferty, accessible, but, associatesassistants, bergman, archbishop, attackcensor, attacking, bear
# - Topic 5: caucus, acct, bauman, accessible, banremove, censored, bcll, alert, binney, already
# - Topic 6: but, abuse, bcll, case, aprilmay, bay, backgroundsoroshusseinhrcmsmsocialmhollywood, bissau, admr, activeongoing
# - Topic 7: but, bauman, censor, attackcensor, believer, caught, aircraft, cataloging, cafferty, bdt
# - Topic 8: celestial, attackcensor, but, cdef, believer, blood, appear, cannotwill, belongs, armextension
# - Topic 9: acooper, but, catalog, benin, attackcensor, activeongoing, alert, asksed, asap, batten
# - Topic 10: but, cafferty, bauman, accessible, censor, amendment, ashton, attackcensor, bear, by
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 22:
# - Topic 1: crew, chat, crumb, actionable, boy, brought, additionally, creleases, defeating, deceiving
# - Topic 2: censorship, crew, authzgp, client, attack, city, citizenship, century, defeating, bond
# - Topic 3: crew, actionable, chat, against, begun, blackhispanic, bader, boy, brought, defeating
# - Topic 4: chat, crumb, crew, chinanonpublic, actionable, boy, change, defeating, brought, arrange
# - Topic 5: crumb, alleged, declas, brzezinski, defeating, deceiving, crew, declares, comb, brought
# - Topic 6: crew, crumb, actionable, chat, boy, deal, declas, crucial, chose, defeating
# - Topic 7: chat, crumb, aimed, can, comb, actionable, attended, appoint, circulates, aggressively
# - Topic 8: crew, crumb, chat, actionable, brought, declares, declas, defeating, additionally, algos
# - Topic 9: crew, crumb, declared, declares, apache, defection, brought, comb, blame, alarm
# - Topic 10: crumb, crew, additionally, crosharing, actionable, bd, defection, absolutely, adopting, chopper
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Time Window 23:
# - Topic 1: active, chalupa, court, countdown, cybersecurity, asking, bastest, americaeconomy, dca, bo
# - Topic 2: countdown, chalupa, court, adj, datesweek, chagaris, dean, cannotwill, brave, active
# - Topic 3: court, countdown, darpa, chalupa, assisthardpush, blockobstruct, bo, dean, active, caution
# - Topic 4: brave, darpa, crane, anniversary, allvehiclesofdeliveryremoved, counterintelligence, corp, construction, alltime, blood
# - Topic 5: countdown, chalupa, court, bo, borderwall, darpagoog, active, chinarussia, apart, activated
# - Topic 6: chalupa, adj, datesweek, balance, combination, court, countdown, darpa, courtroom, agree
# - Topic 7: commschiefs, captured, chris, communicate, clue, court, barrel, da, attestation, apparatus
# - Topic 8: chalupa, court, active, countdown, cybersecurity, comm, dca, bo, americaeconomy, bastest
# - Topic 9: david, chalupa, countdown, carnal, caliber, bo, again, counterevents, anarchy, calm
# - Topic 10: court, data, baltimore, affecting, cleaned, cfr, cen, buz, colony, cybersecurity
#   - Topic 1
#   - Topic 2
#   - Topic 3
#   - Topic 4
#   - Topic 5
#   - Topic 6
#   - Topic 7
#   - Topic 8
#   - Topic 9
#   - Topic 10
#
# Common Crime-related Terms:
# checkinzdestfc, antigay, advisory, challenged, ask, activated, accepting, barter, certain, attackcensor, assist, cdef, cancerbaby, cheatin, branch, carrier, comprehensive, armor, alias, accord, buckle, cataloging, animal, antifacom, borderwall, available, cheap, alien, collectionnsahomeland, assistset, declared, brady, balance, competitor, aug, betrayer, arrival, bang, checker, amount, asstd, arm, anon, childrens, asks, admit, affiliated, cage, blmcom, armextension, aggression, clone, anything, backwards, allow, alive, absolute, car, block, address, ban, comb, ascertained, close, directly, bcrc, coincide, charge, around, arabia, brad, alarm, arena, capturekill, david, cult, arising, assembled, allen, chinask, arent, baltimore, activist, az, adult, boring, consulting, careless, discovered, altered, betrays, agencycapersonnelremoval, burned, capturing, apostate, ascension, blm, benedict, beg, age, cease, closedlimited, acted, announcement, brought, australian, called, barrwhitaker, ceased, appears, audio, beforeafter, crosharing, communicate, clinic, armmsm, beth, creleases, bh, boat, centrist, agdag, coat, alexandra, anyone, bahamas, crew, blackwater, calculated, appointed, calm, absolutely, commsatfalse, castlerock, actress, adapt, bought, customized, chip, awandwspaki, anons, coie, atmosphere, causing, adolf, apparatus, changing, buildcode, afghanistan, audit, babcs, closed, convert, activecommence, benavides, comm, begun, banco, affair, ai, book, anita, breastplate, charging, baited, censorship, appoints, adopting, capability, antiabortion, cdc, beverly, caucus, brzezinski, bravo, bio, armenia, addressed, boygirl, checkmate, barrdurham, cleaned, da, almost, cite, betterment, announced, confsilex, cfr, apostolic, alt, bull, ashamed, building, asleep, assistant, arianna, bar, career, according, click, chemical, ammunition, authwh, chairman, capture, authzgp, catch, accuser, datesweek, center, cafferty, clean, amanda, cancel, alterchange, biden, calculating, advocate, bahrain, buhr, condone, averted, case, antisessions, bigamist, await, ancestry, chikd, conquer, appeal, coi, candidatepresident, active, attitude, attack, bangko, countered, barlow, confdwwconoffdark, andre, complex, bronfmans, counterevents, aiding, bugged, begging, communicating, carlin, deceiving, awaiting, closure, defeating, change, attended, affect, aggimagefailure, asecretplanbyagrouptodosomethingunlawfulorharmful, cfi, bruce, competition, comms, chaired, beauty, below, acc, assemblyman, agent, branded, antiracist, amended, clasq, bcll, barack, algo, bird, blame, bail, dean, blackout, autotruth, batter, apps, brainwashed, cc, crumb, alwaleed, assembly, attendance, arranging, castro, courtroom, authentication, connectionsec, assetagent, advantage, bdtfalse, appellate, antigod, castleonline, bolton, city, coming, broker, antilles, disguised, binney, bed, aimed, channel, advance, antisoviet, beam, clue, assisthardpush, bury, addy, brand, arrested, arbiter, barr, bros, counterintelligence, clock, cripple, boom, attackwarning, by, attach, assaulted, attempted, data, asap, boalexander, absurd, alq, californiaif, awareness, accurately, accuracy, coerced, backup, bd, deleteinstall, commanding, affirm, beast, aggressionslander, bunch, crane, authorization, cmbo, comparecontrast, construction, accelerated, childrenpeople, actblue, calendar, basement, affecting, countdown, christian, actionable, actspub, adj, anarchy, barrel, bit, archive, anticapitalistic, assertive, commoninterest, christie, architect, adoption, boost, boooom, bronfman, bay, campbell, authenticity, americaisbacktoleading, accumulate, at, collective, aghrc, blessing, build, budget, bear, closedloop, began, chinaqatar, approvedpage, amend, botsgoog, bravest, accounted, alltime, about, admissible, april, backgroundsoroshusseinhrcmsmsocialmhollywood, battery, balslbtczajxk, black, clayton, allpower, bocsbonocsnobo, comfy, appreciation, cayman, ammo, allvehiclesofdeliveryremoved, chanting, accessible, al ...
